# %%
import pandas as pd
import matplotlib.pyplot as plt

city = 'St. Louis'
review_data = pd.read_csv(f'../filtered_cities/{city}_review.csv')

review_data
# Out:
#                     review_id                 user_id             business_id  \
# 0      NvusujU9_5pIUbn9SZ6hMA  nbVYXmDUO6XH-wvhY62uvg  XMGjDIAFbu9VSmWDs-Ev5w
# 1      vHOeBa7aMA_na4rfS2Db5A  QmPSBBPFVj3_G2MceMttDg  0z45rM2paE-O-6w63GEi6g
# 2      hG9RTxxivb0ZXzEk4JXTXA  PuvfPONWyhdtRVPWu7kLpQ  -bGw8ARHQucKWEHEkxpGFw
# 3      zIVkwgahZjOneChZFUYY4g  Z1PqEZMXMkcpa7T_YQFcvg  w6z28easvQLND722s4pNvw
# 4      DLczAuvMAlAnY5EeDGhTVg  zHtRMvNaLWYC39WctI2Neg  Z2ltNYVxmLaLGNVB7yFWQA
# ...                       ...                     ...                     ...
# 63446  OgoBp7fbXnLSKvsQb4O_tw  Rh1Su109GN7efi3MlshFPQ  dHS3dwYAGIya7yd1d3J1DA
# 63447  Q7e8EtZMmdknDrQE7huMoQ  9HpMD7QFhZyQJ6FuotwNWQ  jJKmOo4aeo_NanXQn1gjiw
# 63448  zzMW6zbsFaQMjoGu2bGVdA  c777s7tUlrWkM0BIR9JNyQ  yVZtL5MmrpiivyCIrVkGgA
# 63449  scgoa60EvhW2Mz7JMqLYGw  5JgyYnsn-j0hOAE_znph9A  2FkuiaTdGKS45XkJOKMfGA
# 63450  M7NAWZ9P99ucR66LrxrUOQ  6YRmtPVvnD_mexQifxAJsg  IkjBNJvMZhea1c3j2H2Ahw
#
# ...

# %%
review_data['date'] = pd.to_datetime(review_data['date'])
review_data.set_index('date', inplace=True)

# %%
# make a time series plot with the number of reviews per day
reviews_over_time = review_data.resample('D').size()

plt.figure(figsize=(10, 6))
reviews_over_time.plot(color='skyblue')
plt.title('Number of Reviews Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Reviews')
plt.grid(True)
plt.show()

# %%
# make a time series plot with the number of reviews per week
reviews_over_time = review_data.resample('W').size()

# print number of points on reviews_over_time
print(len(reviews_over_time))

plt.figure(figsize=(10, 6))
reviews_over_time.plot(color='skyblue')
plt.title('Number of Reviews Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Reviews')
plt.grid(True)
plt.show()
# Out:
# 871

# %%
# make a time series plot with the number of reviews per month
reviews_over_time = review_data.resample('M').size()

plt.figure(figsize=(10, 6))
reviews_over_time.plot(color='skyblue')
plt.title('Number of Reviews Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Reviews')
plt.grid(True)
plt.show()

# %%
# make a time series plot with the number of reviews per year
reviews_over_time = review_data.resample('Y').size()

plt.figure(figsize=(10, 6))
reviews_over_time.plot(color='skyblue')
plt.title('Number of Reviews Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Reviews')
plt.grid(True)
plt.show()
